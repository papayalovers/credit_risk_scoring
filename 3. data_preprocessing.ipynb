# %%
from src.utils import (
    PreprocessingPipeline, 
    ConfigManager, 
    SerializationManager
)
import pandas as pd
import numpy as np 
import joblib

# %% [markdown]
# # 1. Load Config

# %%
# Path Config
CONFIG_PATH = 'config/config.yaml'
config_manager = ConfigManager(config_path=CONFIG_PATH)
config = config_manager.load_config()

# %% [markdown]
# # 2. Deserialized Data

# %%
# Load serilization manager
serilization_manager = SerializationManager(config=config)
# Deserialize processed data train
X_train = serilization_manager.deserialize_data('X_train')
y_train = serilization_manager.deserialize_data('y_train')
# Deserialize processed data validation
X_valid = serilization_manager.deserialize_data('X_valid')
y_valid = serilization_manager.deserialize_data('y_valid')
# Deserialize processed data test
X_test = serilization_manager.deserialize_data('X_test')
y_test = serilization_manager.deserialize_data('y_test')
# Out:
# Deserialized data loaded from data/processed/X_train.pkl
# Deserialized data loaded from data/processed/y_train.pkl
# Deserialized data loaded from data/processed/X_valid.pkl
# Deserialized data loaded from data/processed/y_valid.pkl
# Deserialized data loaded from data/processed/X_test.pkl
# Deserialized data loaded from data/processed/y_test.pkl

# %% [markdown]
# # 3. Data Preprocessing

# %%
# Drop duplicates
X_train = X_train.drop_duplicates()
print(f"Shape after drop duplicates: {X_train.shape}")
print(f"Number of duplicates: {X_train.duplicated().sum()}")
# Out:
# Shape after drop duplicates: (25946, 11)
# Number of duplicates: 0

# %%
# Delete invalid data
cond1 = X_train['person_age'] <= 100
cond2 = X_train['person_emp_length'] <= 50
# --- IGNORE ---
X_train = X_train[cond1 & cond2]
print(f"Shape after drop invalid data: {X_train.shape}")
# Out:
# Shape after drop invalid data: (25230, 11)

# %% [markdown]
# ### Handling Missing Value

# %%
def num_imputer(data: pd.DataFrame, cols: list) -> object:
    from sklearn.impute import SimpleImputer
    num_imputer = SimpleImputer(strategy='median', missing_values=np.nan)
    num_imputer.fit(data[cols])
    return num_imputer

def num_imputer_transform(data: pd.DataFrame, cols: list, imputer: object) -> pd.DataFrame:
    imputed_data = imputer.transform(data[cols])
    result_df = pd.DataFrame(
        data=imputed_data, index=data.index, columns=cols
    )
    # drop data
    data.drop(cols, axis=1, inplace=True)
    # hasil
    data = pd.concat([data, result_df], axis=1)
    return data

# %%
# Set Col name
col = X_train.describe().columns

imputer = num_imputer(data=X_train, cols=col)
# do imputer with median
X_train = num_imputer_transform(data=X_train, imputer=imputer, cols=col)
X_valid = num_imputer_transform(data=X_valid, imputer=imputer, cols=col)
X_test = num_imputer_transform(data=X_test, imputer=imputer, cols=col)

# %% [markdown]
# ### 1. Pipeline Log Transform

# %%
# Define Preprocessing Pipeline for Log Transform
prep_log = PreprocessingPipeline(config=config, is_log_transform=True, is_robust=False)
# Fitting
x_train_log = prep_log.fit_transform(X_train)
x_valid_log = prep_log.transform(X_valid)
x_test_log = prep_log.transform(X_test)
# Simpan Pipeline Log Transform  
prep_log.save_pipeline()
# Out:
# Pipeline saved to models/preprocessing_pipeline_log.pkl

# %%
# Update Config
PATH = 'models/preprocessing_pipeline_log.pkl'
config_manager.update_config(key='path.pipeline.log', value=PATH)
# Out:
# Updated: path.pipeline.log = models/preprocessing_pipeline_log.pkl

# %%
x_train_log.sample(5)
# Out:
#        person_age  person_income  person_emp_length  loan_amnt  loan_int_rate  \
# 23959    3.583519      11.034906           2.302585   9.472782       2.327278
# 4597     3.258097      10.637417           1.945910   8.294300       1.944481
# 22662    3.367296      10.950824           2.639057   9.169623       2.830858
# 11977    3.178054      10.714440           1.098612   9.323758       2.450143
# 6110     3.135494       9.798183           1.098612   8.699681       2.030776
#
#        loan_percent_income  cb_person_cred_hist_length  \
# 23959             0.190620                    2.397895
# 4597              0.095310                    1.098612
# 22662             0.157004                    2.302585
# 11977             0.223144                    1.098612
# 6110              0.285179                    1.098612
#
#        person_home_ownership_OTHER  person_home_ownership_OWN  \
# 23959                          0.0                        0.0
# 4597                           0.0                        0.0
# 22662                          0.0                        0.0
# 11977                          0.0                        0.0
# 6110                           0.0                        0.0
#
#        person_home_ownership_RENT  ...  loan_intent_MEDICAL  \
# 23959                         0.0  ...                  0.0
# 4597                          0.0  ...                  0.0
# 22662                         0.0  ...                  0.0
# 11977                         1.0  ...                  0.0
# 6110                          1.0  ...                  0.0
#
#        loan_intent_PERSONAL  loan_intent_VENTURE  loan_grade_2  loan_grade_3  \
# 23959                   0.0                  0.0           1.0           0.0
# 4597                    0.0                  0.0           0.0           0.0
# 22662                   1.0                  0.0           0.0           1.0
# 11977                   1.0                  0.0           1.0           0.0
# 6110                    0.0                  1.0           0.0           0.0
#
#        loan_grade_4  loan_grade_5  loan_grade_6  loan_grade_7  \
# 23959           0.0           0.0           0.0           0.0
# 4597            0.0           0.0           0.0           0.0
# 22662           0.0           0.0           0.0           0.0
# 11977           0.0           0.0           0.0           0.0
# 6110            0.0           0.0           0.0           0.0
#
#        cb_person_default_on_file_1
# 23959                          0.0
# 4597                           0.0
# 22662                          1.0
# 11977                          0.0
# 6110                           0.0
#
# [5 rows x 22 columns]

# %% [markdown]
# ### 2. Pipeline RobustScaler

# %%
# Define Preprocessing Pipeline for Robust Scaler
prep_rob = PreprocessingPipeline(config=config, is_log_transform=False, is_robust=True)
# Fitting
x_train_rob = prep_rob.fit_transform(X_train)
x_valid_rob = prep_rob.transform(X_valid)
x_test_rob = prep_rob.transform(X_test)
# Simpan Pipeline Log Robust Scaler  
prep_rob.save_pipeline()
# Out:
# Pipeline saved to models/preprocessing_pipeline_robust.pkl

# %%
# Update Config
PATH = 'models/preprocessing_pipeline_robust.pkl'
config_manager.update_config(key='path.pipeline.robust', value=PATH)
# Out:
# Updated: path.pipeline.robust = models/preprocessing_pipeline_robust.pkl

# %%
x_train_rob.sample(5)
# Out:
#        person_age  person_income  person_emp_length  loan_amnt  loan_int_rate  \
# 20271    0.285714       0.136139               -0.6  -0.533333      -0.008565
# 6190    -0.428571      -0.747525               -0.4  -0.266667       0.000000
# 5486     0.000000       0.099010               -0.8  -0.400000      -0.824411
# 27141    0.285714      -0.817624                0.0  -0.866667      -1.062099
# 32140    1.714286       0.544554                0.8  -0.233333      -0.905782
#
#        loan_percent_income  cb_person_cred_hist_length  \
# 20271            -0.571429                         0.8
# 6190              0.571429                        -0.2
# 5486             -0.500000                        -0.4
# 27141            -0.571429                         0.6
# 32140            -0.500000                         2.4
#
#        person_home_ownership_OTHER  person_home_ownership_OWN  \
# 20271                          0.0                        0.0
# 6190                           0.0                        0.0
# 5486                           0.0                        0.0
# 27141                          0.0                        0.0
# 32140                          0.0                        0.0
#
#        person_home_ownership_RENT  ...  loan_intent_MEDICAL  \
# 20271                         1.0  ...                  0.0
# 6190                          1.0  ...                  0.0
# 5486                          1.0  ...                  0.0
# 27141                         1.0  ...                  1.0
# 32140                         0.0  ...                  0.0
#
#        loan_intent_PERSONAL  loan_intent_VENTURE  loan_grade_2  loan_grade_3  \
# 20271                   0.0                  0.0           1.0           0.0
# 6190                    0.0                  1.0           0.0           1.0
# 5486                    1.0                  0.0           0.0           0.0
# 27141                   0.0                  0.0           0.0           0.0
# 32140                   0.0                  1.0           0.0           0.0
#
#        loan_grade_4  loan_grade_5  loan_grade_6  loan_grade_7  \
# 20271           0.0           0.0           0.0           0.0
# 6190            0.0           0.0           0.0           0.0
# 5486            0.0           0.0           0.0           0.0
# 27141           0.0           0.0           0.0           0.0
# 32140           0.0           0.0           0.0           0.0
#
#        cb_person_default_on_file_1
# 20271                          0.0
# 6190                           1.0
# 5486                           0.0
# 27141                          0.0
# 32140                          0.0
#
# [5 rows x 22 columns]

# %% [markdown]
# ### 3. Pipeline Log Transform + Robust

# %%
# Define Preprocessing Pipeline for Robust Scaler
prep_logrob = PreprocessingPipeline(config=config, is_log_transform=True, is_robust=True)
# Fitting
x_train_logrob = prep_logrob.fit_transform(X_train)
x_valid_logrob = prep_logrob.transform(X_valid)
x_test_logrob = prep_logrob.transform(X_test)
# Simpan Pipeline Log Robust Scaler  
prep_logrob.save_pipeline()
# Out:
# Pipeline saved to models/preprocessing_pipeline_log_robust.pkl

# %%
# Update Config
PATH = 'models/preprocessing_pipeline_log_robust.pkl'
config_manager.update_config(key='path.pipeline.log_robust', value=PATH)
# Out:
# Updated: path.pipeline.log_robust = models/preprocessing_pipeline_log_robust.pkl

# %%
x_train_logrob.sample(5)
# Out:
#        person_age  person_income  person_emp_length  loan_amnt  loan_int_rate  \
# 17510   -3.254446      -1.385862          -0.580278  -1.065368      -1.894809
# 5889    -3.254446      -1.385872          -0.441648  -1.065439      -1.776456
# 4906    -3.254446      -1.385876          -0.360555  -1.065531      -1.770319
# 3018    -3.266358      -1.385871          -0.661371  -1.065591      -1.871469
# 14639   -3.254446      -1.385874          -0.800000  -1.065653      -1.882821
#
#        loan_percent_income  cb_person_cred_hist_length  \
# 17510             0.465081                   -0.478112
# 5889              0.290145                   -0.478112
# 4906             -0.198445                   -0.478112
# 3018             -0.655222                   -0.478112
# 14639            -0.722927                   -0.478112
#
#        person_home_ownership_OTHER  person_home_ownership_OWN  \
# 17510                          0.0                        0.0
# 5889                           0.0                        0.0
# 4906                           0.0                        0.0
# 3018                           0.0                        0.0
# 14639                          0.0                        0.0
#
#        person_home_ownership_RENT  ...  loan_intent_MEDICAL  \
# 17510                         0.0  ...                  0.0
# 5889                          0.0  ...                  0.0
# 4906                          1.0  ...                  1.0
# 3018                          1.0  ...                  0.0
# 14639                         1.0  ...                  0.0
#
#        loan_intent_PERSONAL  loan_intent_VENTURE  loan_grade_2  loan_grade_3  \
# 17510                   0.0                  0.0           0.0           0.0
# 5889                    0.0                  0.0           0.0           1.0
# 4906                    0.0                  0.0           0.0           1.0
# 3018                    0.0                  1.0           0.0           0.0
# 14639                   1.0                  0.0           0.0           0.0
#
#        loan_grade_4  loan_grade_5  loan_grade_6  loan_grade_7  \
# 17510           0.0           0.0           0.0           0.0
# 5889            0.0           0.0           0.0           0.0
# 4906            0.0           0.0           0.0           0.0
# 3018            0.0           0.0           0.0           0.0
# 14639           0.0           0.0           0.0           0.0
#
#        cb_person_default_on_file_1
# 17510                          0.0
# 5889                           1.0
# 4906                           0.0
# 3018                           0.0
# 14639                          0.0
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Load & test preprocessing pipeline

# %%
test_data = X_valid.sample(5)
# Load pipeline log transform
PATH = config['path']['pipeline']['log']
print(PATH)
prep_log_loaded = joblib.load(PATH)
# Test transformasi
test_data_log = prep_log_loaded.transform(test_data)
test_data_log
# Out:
# models/preprocessing_pipeline_log.pkl
#        person_age  person_income  person_emp_length  loan_amnt  loan_int_rate  \
# 19074    3.332205      10.085851           0.693147   7.673688       2.754934
# 22085    3.496508      10.799596           2.833213   8.748464       2.389680
# 23919    3.401197      11.115771           1.609438   9.210440       2.496506
# 32092    3.713572      10.736331           1.609438   9.903538       2.747912
# 18878    3.526361      10.778977           1.098612   7.313887       2.556452
#
#        loan_percent_income  cb_person_cred_hist_length  \
# 19074             0.086178                    2.079442
# 22085             0.122218                    2.197225
# 23919             0.139762                    2.302585
# 32092             0.357674                    2.639057
# 18878             0.029559                    1.945910
#
#        person_home_ownership_OTHER  person_home_ownership_OWN  \
# 19074                          0.0                        0.0
# 22085                          0.0                        0.0
# 23919                          0.0                        0.0
# 32092                          0.0                        0.0
# 18878                          0.0                        0.0
#
#        person_home_ownership_RENT  ...  loan_intent_MEDICAL  \
# 19074                         1.0  ...                  1.0
# 22085                         1.0  ...                  1.0
# 23919                         0.0  ...                  0.0
# 32092                         1.0  ...                  0.0
# 18878                         1.0  ...                  0.0
#
#        loan_intent_PERSONAL  loan_intent_VENTURE  loan_grade_2  loan_grade_3  \
# 19074                   0.0                  0.0           0.0           1.0
# 22085                   0.0                  0.0           1.0           0.0
# 23919                   0.0                  0.0           1.0           0.0
# 32092                   0.0                  0.0           0.0           0.0
# 18878                   0.0                  1.0           1.0           0.0
#
#        loan_grade_4  loan_grade_5  loan_grade_6  loan_grade_7  \
# 19074           0.0           0.0           0.0           0.0
# 22085           0.0           0.0           0.0           0.0
# 23919           0.0           0.0           0.0           0.0
# 32092           1.0           0.0           0.0           0.0
# 18878           0.0           0.0           0.0           0.0
#
#        cb_person_default_on_file_1
# 19074                          0.0
# 22085                          0.0
# 23919                          0.0
# 32092                          1.0
# 18878                          0.0
#
# [5 rows x 22 columns]

# %%
test_data
# Out:
#       person_home_ownership        loan_intent loan_grade  \
# 19074                  RENT            MEDICAL          C
# 22085                  RENT            MEDICAL          B
# 23919              MORTGAGE  DEBTCONSOLIDATION          B
# 32092                  RENT  DEBTCONSOLIDATION          D
# 18878                  RENT            VENTURE          B
#
#       cb_person_default_on_file  person_age  person_income  person_emp_length  \
# 19074                         N        27.0        24000.0                1.0
# 22085                         N        32.0        49000.0               16.0
# 23919                         N        29.0        67222.0                4.0
# 32092                         Y        40.0        45996.0                4.0
# 18878                         N        33.0        48000.0                2.0
#
#        loan_amnt  loan_int_rate  loan_percent_income  \
# 19074     2150.0          14.72                 0.09
# 22085     6300.0           9.91                 0.13
# 23919    10000.0          11.14                 0.15
# 32092    20000.0          14.61                 0.43
# 18878     1500.0          11.89                 0.03
#
#        cb_person_cred_hist_length
# 19074                         7.0
# 22085                         8.0
# 23919                         9.0
# 32092                        13.0
# 18878                         6.0
